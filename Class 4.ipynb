# %% [markdown]
# # Doubly Linked Lists

# %%
class DoublyLinkedList:
    class __Node:
        def __init__(self, data):
            self.data = data
            self.next = None
            self.prev = None

    def __init__(self):
        self.head = None
        self.tail = None

    def __str__(self):
        out = "["
        current = self.head
        if current:
            out += "%s" % repr(current.data)
            current = current.next
            while current:
                out += ", %s" % repr(current.data)
        out += "]"
        return out

    def append(self, value):
        new_node = self.__Node(value)
        if not self.head:
            self.head = new_node
            self.tail = new_node
        else:
            #current = self.head
            #while current.next:
                #current = current.next
            #current.next = new_node
            #new_node.prev = current
            #self.tail = new_node
            self.tail = new_node
            new_node.prev = self.tail

    def remove(self, value):
        found = False
        if self.head:
            current = self.head
            while current and not found:
                if current.data == value:
                    found = True
                else:
                    current = current.next
            if found:
                if current == self.head:
                    self.head = self.head.next
                else:
                    prev_node = current.prev
                    next_node = current.next
                    prev_node.next = next_node # this could be a None type
                    if next_node:
                        next_node.prev = prev_node
                    if current == self.tail:
                        self.tail = current.prev
        raise ValueError("Value not found in list")
                    
                    
        # removes the first instance of Node that contains the target value
        #if not self.head:
         #   self.head = target
       # else:
        #    current.data = current.next
         #   while current.next:
          #      current = current.next
           # current.next = target
            #target.prev = current
            #if:
            

    def insert(self, index, value):
        # inserts a new node with the target value before the index
        pass

    def __len__(self):
        current = self.head
        count = 0
        while current:
            current = current.next
            count += 1
        return count

# %% [markdown]
# need to define target value. if not head, go to next. current.next until the target is found. then remove reference from next and previous. exit which removes current. if it is head and tail are set to None then remove. If no Nodes can be found, exit. if not tail, then.

# %% [markdown]
# # Problem 1
#
# ## Create a class called Matrix which meets the following creiteria:
#
# ### Criteria
# 1. The Matrix class must receive, in its constructor (or `__init__` method): "rows" and "columns".
# 2. The Matrix class must be able to generate lists of lists, using our DoublyLinkedList class (above).
# 3. The resulting matrix must have `rows` equal to the parameter of the same name.
# 4. The resulting matrix must have `columns` equal to the parameter of the same name.
#
# ### Bonus
# Make it so that your matrix is displayed like this when printing it (in other words, rendering it as a string):
# ```
# 1 2 3
# 4 5 6
# 7 8 9
# ```
# ### Example using python lists
# ```
# no_rows = 3
# no_cols = 3
# matrix = []
# for number in range(no_cols):
#     row_list = []
#     for number in range(no_rows):
#         row_list.append(number)
#     matrix.append(row_list)
#
# print(matrix)
# ```
# print(matrix)
# for col in matrix:
#     temp = ""
#     for row in col:
#         temp += "%s " % row
#     print("%s\n")

# %%
no_rows = 3
no_cols = 3
matrix = []
for number in range(no_cols):
    row_list = []
    for number in range(no_rows):
        row_list.append(number)
    matrix.append(row_list)

print(matrix)
for col in matrix:
    temp = ""
    for row in col:
        temp += "%s " % row
    print("%s" % temp)
# Out:
# [[0, 1, 2], [0, 1, 2], [0, 1, 2]]
# 0 1 2
# 0 1 2
# 0 1 2

# %%
class Matrix:
    def __init__(self, rows, columns):
        self.rows = rows
        self.cols = cols
        self.matrix = DoublyLinkedList()

    def insert_row(self, row_list):
        if len(self.matrix) < self.rows:
            self.matrix.append(row_list)
        raise IndexError("Maxx rows exceeded")

    def insert_col_value(self, values=""):
        colu_list = DoublyLinkedList()
        for value in values.split(","):
            if len(col_list) < self.cols:
                col_list.append(value)
            else:
                raise IndexError("Value list too long")
        
    def __str__(self):
        for col in matrix:
            temp = ""
            for row in col:
                temp += "%s " % row
        print("%s" % temp)

no_rows = 3
no_cols = 3
matrix = []
for number in range(no_cols):
    row_list = []
    for number in range(no_rows):
        row_list.append(number)
    matrix.append(row_list)

# %%
row_list.append(1)

# %%
matrix.append(1)
